# %%
from datetime import datetime
import json
import pandas as pd
import random
import uuid
from faker import Faker
import os

fake = Faker()
# Data without any Anomalies

num_rows = 2000  # Define the number of rows
num_rows_anomalies = 10  # Define the number of rows
num_rows_anomalies_covered = 100  # Define the number of rows
num_rows_anomalies_documents = 100  # Define the number of rows
num_rows_anomalies_claim_limit = 100  # Define the number of rows
num_rows_anomalies_hospitalized_date = 100  # Define the number of rows
num_rows_anomalies_renewal_date = 100  # Define the number of rows
num_rows_anomalies_policy_date = 100  # Define the number of rows
num_rows_anomalies_start_date = 300  # Define the number of rows
num_rows_anomalies_benefits = 100  # Define the number of rows

billing_frequencies = ["Monthly", "Quarterly", "Annually"]
fraud_statuses = ["Approved", "Rejected"]
benefit_types = ["Hospitalisation Benefits"]
policy_types = ["Individual", "Corporate", "Family"]
policy_name = ["Comprehensive Health Plan"]
# Load Health Insurance Plans & Benefits Mapping


data = []
for _ in range(num_rows):
    claim_limit = random.randint(5000, 100000)  # Generate Claim Limit first
    total_amount = random.randint(1000, claim_limit)  # Ensure Total Amount is always ≤ Claim Limit
    start_date = fake.date_this_decade()
    end_date = start_date + pd.DateOffset(years=1)
    hospitalized_date = fake.date_between_dates(date_start=start_date, date_end=end_date)
    renewal_date = end_date  + pd.DateOffset(days=random.randint(1, 365))

    covered = "Yes"
    documents_submitted = "Yes"


    # Fraud History Rule: If Covered = Yes & Documents Submitted = Yes, Approve
    fraud_status = "Approved"

    data.append([
        str(uuid.uuid4()),  # Provider ID
        f"CPT-{random.randint(10000, 99999)}",  # Procedure codes/CPT Code
        random.choice(billing_frequencies),  # Billing frequency
        str(uuid.uuid4()),  # Patient ID
        total_amount,  # Total amount (Validated)
        fake.name(),  # Doctor
        fake.company(),  # Hospital
        fake.sentence(),  # Diagnosis Report
        fake.sentence(),  # Discharge Summary
        fake.sentence(),  # Prescriptions and Bills
        random.randint(1000, 99999),  # Hospital Bills
        fake.company(),  # Insurance Company Name
        fraud_status,  # Fraud history approval/rejection status (Validated)
        fake.phone_number(),  # Contact Details
        fake.company(),  # Network Partners
        random.choice(benefit_types),  # Benefits
        str(uuid.uuid4()),  # Policy Number
        random.choice(policy_types),  # Policy type
        renewal_date,  # Renewal Date (Validated)
        claim_limit,  # Claim limits (Validated)
        random.randint(100, 1000),  # Premium amount
        start_date,  # Start Date
        end_date,  # End Date
        fake.iban(),  # Bank Account
        str(uuid.uuid4()),  # Policy Number (Claim)
        fake.name(),  # Policy Holder Name
        fake.address(),  # Address
        fake.phone_number(),  # Phone Number
        fake.email(),  # Email
        covered,  # Covered status
        hospitalized_date,  #Hospitalized Date (Validated)
        random.randint(1000, 10000),  # Treatment expenses
        documents_submitted,  # Claim Documents Submitted
        random.choice(["Disease-Specific Health Insurance Plans", "Senior Citizen Health Insurance Plans"])  # Policy Name
    ])

# %%
# covered with No , Not Approved
for _ in range(num_rows_anomalies_covered):
    claim_limit = random.randint(5000, 100000)  # Generate Claim Limit first
    total_amount = random.randint(1000, claim_limit)  # Ensure Total Amount is always ≤ Claim Limit
    start_date = fake.date_this_decade()
    end_date = start_date + pd.DateOffset(years=1)
    hospitalized_date = fake.date_between_dates(date_start=start_date, date_end=end_date)
    renewal_date = end_date  + pd.DateOffset(days=random.randint(1, 365))

    covered = "No"
    documents_submitted = "Yes"


    # Fraud History Rule: If Covered = Yes & Documents Submitted = Yes, Approve
    fraud_status = "Rejected"

    data.append([
        str(uuid.uuid4()),  # Provider ID
        f"CPT-{random.randint(10000, 99999)}",  # Procedure codes/CPT Code
        random.choice(billing_frequencies),  # Billing frequency
        str(uuid.uuid4()),  # Patient ID
        total_amount,  # Total amount (Validated)
        fake.name(),  # Doctor
        fake.company(),  # Hospital
        fake.sentence(),  # Diagnosis Report
        fake.sentence(),  # Discharge Summary
        fake.sentence(),  # Prescriptions and Bills
        random.randint(1000, 99999),  # Hospital Bills
        fake.company(),  # Insurance Company Name
        fraud_status,  # Fraud history approval/rejection status (Validated)
        fake.phone_number(),  # Contact Details
        fake.company(),  # Network Partners
        random.choice(benefit_types),  # Benefits
        str(uuid.uuid4()),  # Policy Number
        random.choice(policy_types),  # Policy type
        renewal_date,  # Policy Date (Validated)
        claim_limit,  # Claim limits (Validated)
        random.randint(100, 1000),  # Premium amount
        start_date,  # Start Date
        end_date,  # End Date
        fake.iban(),  # Bank Account
        str(uuid.uuid4()),  # Policy Number (Claim)
        fake.name(),  # Policy Holder Name
        fake.address(),  # Address
        fake.phone_number(),  # Phone Number
        fake.email(),  # Email
        covered,  # Covered status
        fake.date_this_decade(),  # Hospitalized Date
        random.randint(1000, 10000),  # Treatment expenses
        documents_submitted,  # Claim Documents Submitted
        random.choice(["Disease-Specific Health Insurance Plans", "Senior Citizen Health Insurance Plans"])  # Policy Name
    ])

# %%
#documents_submitted = No, Rejected
for _ in range(num_rows_anomalies_documents):
    claim_limit = random.randint(5000, 100000)  # Generate Claim Limit first
    total_amount = random.randint(1000, claim_limit)  # Ensure Total Amount is always ≤ Claim Limit
    start_date = fake.date_this_decade()
    end_date = start_date + pd.DateOffset(years=1)
    renewal_date = fake.date_between_dates(date_start=start_date, date_end=end_date)

    covered = "Yes"
    documents_submitted = "No"


    # Fraud History Rule: If Covered = Yes & Documents Submitted = Yes, Approve
    fraud_status = "Rejected"

    data.append([
        str(uuid.uuid4()),  # Provider ID
        f"CPT-{random.randint(10000, 99999)}",  # Procedure codes/CPT Code
        random.choice(billing_frequencies),  # Billing frequency
        str(uuid.uuid4()),  # Patient ID
        total_amount,  # Total amount (Validated)
        fake.name(),  # Doctor
        fake.company(),  # Hospital
        fake.sentence(),  # Diagnosis Report
        fake.sentence(),  # Discharge Summary
        fake.sentence(),  # Prescriptions and Bills
        random.randint(1000, 99999),  # Hospital Bills
        fake.company(),  # Insurance Company Name
        fraud_status,  # Fraud history approval/rejection status (Validated)
        fake.phone_number(),  # Contact Details
        fake.company(),  # Network Partners
        random.choice(benefit_types),  # Benefits
        str(uuid.uuid4()),  # Policy Number
        random.choice(policy_types),  # Policy type
        renewal_date,  # Policy Date (Validated)
        claim_limit,  # Claim limits (Validated)
        random.randint(100, 1000),  # Premium amount
        start_date,  # Start Date
        end_date,  # End Date
        fake.iban(),  # Bank Account
        str(uuid.uuid4()),  # Policy Number (Claim)
        fake.name(),  # Policy Holder Name
        fake.address(),  # Address
        fake.phone_number(),  # Phone Number
        fake.email(),  # Email
        covered,  # Covered status
        fake.date_this_decade(),  # Hospitalized Date
        random.randint(1000, 10000),  # Treatment expenses
        documents_submitted,  # Claim Documents Submitted
        random.choice(["Disease-Specific Health Insurance Plans", "Senior Citizen Health Insurance Plans"])  # Policy Name
    ])

# %%
# Claim limit < Total Amount, Rejected
for _ in range(num_rows_anomalies_claim_limit):
    claim_limit = random.randint(5000, 100000)  # Generate Claim Limit first
    total_amount = random.randint(claim_limit, 100000)  # Ensure Total Amount is always ≤ Claim Limit
    start_date = fake.date_this_decade()
    end_date = start_date + pd.DateOffset(days=random.randint(30, 365))
    renewal_date = end_date  + pd.DateOffset(years=1)
    hospitalized_date = fake.date_between_dates(date_start=start_date, date_end=end_date)

    covered = "Yes"
    documents_submitted = "Yes"

    # Fraud History Rule: If Covered = Yes & Documents Submitted = Yes, Approve
    fraud_status = "Rejected"

    data.append([
        str(uuid.uuid4()),  # Provider ID
        f"CPT-{random.randint(10000, 99999)}",  # Procedure codes/CPT Code
        random.choice(billing_frequencies),  # Billing frequency
        str(uuid.uuid4()),  # Patient ID
        total_amount,  # Total amount (Validated)
        fake.name(),  # Doctor
        fake.company(),  # Hospital
        fake.sentence(),  # Diagnosis Report
        fake.sentence(),  # Discharge Summary
        fake.sentence(),  # Prescriptions and Bills
        random.randint(1000, 99999),  # Hospital Bills
        fake.company(),  # Insurance Company Name
        fraud_status,  # Fraud history approval/rejection status (Validated)
        fake.phone_number(),  # Contact Details
        fake.company(),  # Network Partners
        random.choice(benefit_types),  # Benefits
        str(uuid.uuid4()),  # Policy Number
        random.choice(policy_types),  # Policy type
        renewal_date,  # Policy Date (Validated)
        claim_limit,  # Claim limits (Validated)
        random.randint(100, 1000),  # Premium amount
        start_date,  # Start Date
        end_date,  # End Date
        fake.iban(),  # Bank Account
        str(uuid.uuid4()),  # Policy Number (Claim)
        fake.name(),  # Policy Holder Name
        fake.address(),  # Address
        fake.phone_number(),  # Phone Number
        fake.email(),  # Email
        covered,  # Covered status
        hospitalized_date,  # Hospitalized Date
        random.randint(1000, 10000),  # Treatment expenses
        documents_submitted,  # Claim Documents Submitted
        random.choice(["Disease-Specific Health Insurance Plans", "Senior Citizen Health Insurance Plans"])  # Policy Name
    ])

# %%
#Ploicy Date before Start Date, Rejected
for _ in range(num_rows_anomalies_policy_date):
    claim_limit = random.randint(5000, 100000)  # Generate Claim Limit first
    total_amount = random.randint(1000, claim_limit)  # Ensure Total Amount is always ≤ Claim Limit
    start_date = fake.date_this_decade()
    end_date = start_date + pd.DateOffset(years=1)
    hospitalized_date = fake.date_between_dates(date_start=start_date, date_end=end_date)
    renewal_date = start_date  - pd.DateOffset(days=random.randint(30, 365))

    covered = "Yes"
    documents_submitted = "Yes"


    fraud_status = "Rejected"

    data.append([
        str(uuid.uuid4()),  # Provider ID
        f"CPT-{random.randint(10000, 99999)}",  # Procedure codes/CPT Code
        random.choice(billing_frequencies),  # Billing frequency
        str(uuid.uuid4()),  # Patient ID
        total_amount,  # Total amount (Validated)
        fake.name(),  # Doctor
        fake.company(),  # Hospital
        fake.sentence(),  # Diagnosis Report
        fake.sentence(),  # Discharge Summary
        fake.sentence(),  # Prescriptions and Bills
        random.randint(1000, 99999),  # Hospital Bills
        fake.company(),  # Insurance Company Name
        fraud_status,  # Fraud history approval/rejection status (Validated)
        fake.phone_number(),  # Contact Details
        fake.company(),  # Network Partners
        random.choice(benefit_types),  # Benefits
        str(uuid.uuid4()),  # Policy Number
        random.choice(policy_types),  # Policy type
        renewal_date,  # Policy Date (Validated)
        claim_limit,  # Claim limits (Validated)
        random.randint(100, 1000),  # Premium amount
        start_date,  # Start Date
        end_date,  # End Date
        fake.iban(),  # Bank Account
        str(uuid.uuid4()),  # Policy Number (Claim)
        fake.name(),  # Policy Holder Name
        fake.address(),  # Address
        fake.phone_number(),  # Phone Number
        fake.email(),  # Email
        covered,  # Covered status
        hospitalized_date,  # Hospitalized Date
        random.randint(1000, 10000),  # Treatment expenses
        documents_submitted,  # Claim Documents Submitted
        random.choice(["Disease-Specific Health Insurance Plans", "Senior Citizen Health Insurance Plans"])  # Policy Name
    ])

# %%
#renewal_date After End Date, Rejected
for _ in range(num_rows_anomalies_renewal_date):
    claim_limit = random.randint(5000, 100000)  # Generate Claim Limit first
    total_amount = random.randint(1000, claim_limit)  # Ensure Total Amount is always ≤ Claim Limit
    start_date = fake.date_this_decade()
    end_date = start_date + pd.DateOffset(years=1)
    hospitalized_date = fake.date_between_dates(date_start=start_date, date_end=end_date)
    renewal_date = end_date  + pd.DateOffset(days=random.randint(30, 365))

    covered = "Yes"
    documents_submitted = "Yes"

    fraud_status = "Rejected"

    data.append([
        str(uuid.uuid4()),  # Provider ID
        f"CPT-{random.randint(10000, 99999)}",  # Procedure codes/CPT Code
        random.choice(billing_frequencies),  # Billing frequency
        str(uuid.uuid4()),  # Patient ID
        total_amount,  # Total amount (Validated)
        fake.name(),  # Doctor
        fake.company(),  # Hospital
        fake.sentence(),  # Diagnosis Report
        fake.sentence(),  # Discharge Summary
        fake.sentence(),  # Prescriptions and Bills
        random.randint(1000, 99999),  # Hospital Bills
        fake.company(),  # Insurance Company Name
        fraud_status,  # Fraud history approval/rejection status (Validated)
        fake.phone_number(),  # Contact Details
        fake.company(),  # Network Partners
        random.choice(benefit_types),  # Benefits
        str(uuid.uuid4()),  # Policy Number
        random.choice(policy_types),  # Policy type
        renewal_date,  # Policy Date (Validated)
        claim_limit,  # Claim limits (Validated)
        random.randint(100, 1000),  # Premium amount
        start_date,  # Start Date
        end_date,  # End Date
        fake.iban(),  # Bank Account
        str(uuid.uuid4()),  # Policy Number (Claim)
        fake.name(),  # Policy Holder Name
        fake.address(),  # Address
        fake.phone_number(),  # Phone Number
        fake.email(),  # Email
        covered,  # Covered status
        fake.date_this_decade(),  # Hospitalized Date
        random.randint(1000, 10000),  # Treatment expenses
        documents_submitted,  # Claim Documents Submitted
        random.choice(["Disease-Specific Health Insurance Plans", "Senior Citizen Health Insurance Plans"])  # Policy Name
    ])

# %%
# start_date > end_date, Rejected
for _ in range(num_rows_anomalies_start_date):
    claim_limit = random.randint(5000, 100000)  # Generate Claim Limit first
    total_amount = random.randint(1000, claim_limit)  # Ensure Total Amount is always ≤ Claim Limit
    start_date = fake.date_this_decade()
    end_date_policy = start_date - pd.DateOffset(days=random.randint(30, 365))
    renewal_date = fake.date_between_dates(date_start=start_date, date_end=end_date_policy)
    end_date = start_date - pd.DateOffset(years=1)  # Before start_date
    hospitalized_date = fake.date_between_dates(date_start=start_date, date_end=end_date_policy)
    covered = "Yes"
    documents_submitted = "Yes"


    # Fraud History Rule: If Covered = Yes & Documents Submitted = Yes, Approve
    fraud_status = "Rejected"

    data.append([
        str(uuid.uuid4()),  # Provider ID
        f"CPT-{random.randint(10000, 99999)}",  # Procedure codes/CPT Code
        random.choice(billing_frequencies),  # Billing frequency
        str(uuid.uuid4()),  # Patient ID
        total_amount,  # Total amount (Validated)
        fake.name(),  # Doctor
        fake.company(),  # Hospital
        fake.sentence(),  # Diagnosis Report
        fake.sentence(),  # Discharge Summary
        fake.sentence(),  # Prescriptions and Bills
        random.randint(1000, 99999),  # Hospital Bills
        fake.company(),  # Insurance Company Name
        fraud_status,  # Fraud history approval/rejection status (Validated)
        fake.phone_number(),  # Contact Details
        fake.company(),  # Network Partners
        random.choice(benefit_types),  # Benefits
        str(uuid.uuid4()),  # Policy Number
        random.choice(policy_types),  # Policy type
        renewal_date,  # Policy Date (Validated)
        claim_limit,  # Claim limits (Validated)
        random.randint(100, 1000),  # Premium amount
        start_date,  # Start Date
        end_date,  # End Date
        fake.iban(),  # Bank Account
        str(uuid.uuid4()),  # Policy Number (Claim)
        fake.name(),  # Policy Holder Name
        fake.address(),  # Address
        fake.phone_number(),  # Phone Number
        fake.email(),  # Email
        covered,  # Covered status
        hospitalized_date,  # Hospitalized Date
        random.randint(1000, 10000),  # Treatment expenses
        documents_submitted,  # Claim Documents Submitted
        random.choice(["Disease-Specific Health Insurance Plans", "Senior Citizen Health Insurance Plans"])  # Policy Name
    ])

# %%
#Benefits not in the policy name, Rejected
for _ in range(num_rows_anomalies_benefits):
    claim_limit = random.randint(5000, 100000)  # Generate Claim Limit first
    total_amount = random.randint(1000, claim_limit)  # Ensure Total Amount is always ≤ Claim Limit
    start_date = fake.date_this_decade()
    end_date = start_date + pd.DateOffset(years=1)
    renewal_date = fake.date_between_dates(date_start=start_date, date_end=end_date)
    with open(r"C:\Bits Plani\CAPSTONE\Project_Work\code\main\insurance-fraud-anomaly-analysis\data\health_insurance_plans_benefits_mapping.json") as f:
     health_insurance_plans_benefits_mapping = json.load(f)

    policy_names = list(health_insurance_plans_benefits_mapping.keys())  # Available policy types   
    covered = "Yes"
    documents_submitted = "Yes"

        # Assign a policy name
    policy_name = random.choice(policy_names)

    # Get valid benefits for the selected policy
    valid_benefits = health_insurance_plans_benefits_mapping.get(policy_name, [])

    # Randomly pick benefits
    benefits = random.sample(valid_benefits, min(len(valid_benefits), random.randint(1, 3)))

    # Convert benefit list to a string for easier checks
    benefits_str = ";".join(benefits)

    if benefits:  # Ensure benefits are mapped
        fraud_status = "Approved"
    else:
     fraud_status = "Rejected"  # Set rejected if benefits are not mapped

    data.append([
        str(uuid.uuid4()),  # Provider ID
        f"CPT-{random.randint(10000, 99999)}",  # Procedure codes/CPT Code
        random.choice(billing_frequencies),  # Billing frequency
        str(uuid.uuid4()),  # Patient ID
        total_amount,  # Total amount (Validated)
        fake.name(),  # Doctor
        fake.company(),  # Hospital
        fake.sentence(),  # Diagnosis Report
        fake.sentence(),  # Discharge Summary
        fake.sentence(),  # Prescriptions and Bills
        random.randint(1000, 99999),  # Hospital Bills
        fake.company(),  # Insurance Company Name
        fraud_status,  # Fraud history approval/rejection status (Validated)
        fake.phone_number(),  # Contact Details
        fake.company(),  # Network Partners
        random.choice(benefit_types),  # Benefits
        str(uuid.uuid4()),  # Policy Number
        random.choice(policy_types),  # Policy type
        renewal_date,  # Policy Date (Validated)
        claim_limit,  # Claim limits (Validated)
        random.randint(100, 1000),  # Premium amount
        start_date,  # Start Date
        end_date,  # End Date
        fake.iban(),  # Bank Account
        str(uuid.uuid4()),  # Policy Number (Claim)
        fake.name(),  # Policy Holder Name
        fake.address(),  # Address
        fake.phone_number(),  # Phone Number
        fake.email(),  # Email
        covered,  # Covered status
        fake.date_this_decade(),  # Hospitalized Date
        random.randint(1000, 10000),  # Treatment expenses
        documents_submitted,  # Claim Documents Submitted
        random.choice(["Disease-Specific Health Insurance Plans", "Senior Citizen Health Insurance Plans"])  # Policy Name
    ])

# %%
df = pd.DataFrame(data, columns=[
    "Provider ID", "Procedure codes/CPT Code", "Billing frequency", "Patient ID", "Total amount",
    "Doctor", "Hospital", "Diagnosis Report", "Discharge Summary", "Prescriptions and Bills",
    "Hospital Bills", "Insurance Company Name", "Fraud history approval/rejection status",
    "Contact Details", "Network Partners", "Benefits", "Policy Number", "Policy type",
    "Renewal Date", "Claim limits", "Premium amount", "Start Date", "End Date",
    "Bank Account", "Policy Number (Claim)", "Policy Holder Name", "Address", "Phone Number",
    "Email", "Covered", "Hospitalized Date", "Treatment expenses",
    "Claim Documents Submitted", "Policy Name"
])
df = df.replace(r'\n', ' ', regex=True)  # Replace new lines inside cells
value_counts = df["Fraud history approval/rejection status"].value_counts()
print(value_counts)
df.to_csv("Synthetic_Data_Generated_insurance_data.csv", index=False)

print("Validated synthetic data saved successfully!")
# Out:
# Fraud history approval/rejection status
# Approved    1100
# Rejected     600
# Name: count, dtype: int64
# Validated synthetic data saved successfully!
